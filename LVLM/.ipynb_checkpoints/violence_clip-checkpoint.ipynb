# %%
# Run these in a Colab cell
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu116
# !pip install ftfy regex tqdm
# !pip install git+https://github.com/openai/CLIP.git
# !pip install decord
# !pip install kagglehub
# !pip install codecarbon
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 39.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 20.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 64.7 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy) (0.2.13)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: ftfy
# Successfully installed ftfy-6.3.1
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-zqieaktl
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-zqieaktl
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ftfy in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (6.3.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (24.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (4.67.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (0.21.0+cu124)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (4.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->clip==1.0) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision->clip==1.0) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->clip==1.0) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->clip==1.0) (3.0.2)
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369490 sha256=74e8c30ba78c215f9f00c161f1ea7ad78c9a527c1cccc73d5cbaf2f6b9f55b5a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-751psyxr/wheels/3f/7c/a4/9b490845988bf7a4db33674d52f709f088f64392063872eb9a
# Successfully built clip
# Installing collected packages: clip
# Successfully installed clip-1.0
# Collecting decord
#   Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl.metadata (422 bytes)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from decord) (2.0.2)
# Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 113.0 MB/s eta 0:00:00
# Installing collected packages: decord
# Successfully installed decord-0.6.0
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.11/dist-packages (0.3.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from kagglehub) (24.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (2025.1.31)
# Collecting codecarbon
#   Downloading codecarbon-2.8.3-py3-none-any.whl.metadata (8.7 kB)
# Collecting arrow (from codecarbon)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from codecarbon) (8.1.8)
# Collecting fief-client[cli] (from codecarbon)
#   Downloading fief_client-0.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from codecarbon) (2.2.2)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from codecarbon) (0.21.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from codecarbon) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from codecarbon) (9.0.0)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.11/dist-packages (from codecarbon) (12.0.0)
# Collecting questionary (from codecarbon)
#   Downloading questionary-2.1.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting rapidfuzz (from codecarbon)
#   Downloading rapidfuzz-3.12.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from codecarbon) (2.32.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from codecarbon) (13.9.4)
# Requirement already satisfied: typer in /usr/local/lib/python3.11/dist-packages (from codecarbon) (0.15.2)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from arrow->codecarbon) (2.8.2)
# Collecting types-python-dateutil>=2.8.10 (from arrow->codecarbon)
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl.metadata (2.1 kB)
# Collecting httpx<0.28.0,>=0.21.3 (from fief-client[cli]->codecarbon)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jwcrypto<2.0.0,>=1.4 (from fief-client[cli]->codecarbon)
#   Downloading jwcrypto-1.5.6-py3-none-any.whl.metadata (3.1 kB)
# Collecting yaspin (from fief-client[cli]->codecarbon)
#   Downloading yaspin-3.1.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->codecarbon) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->codecarbon) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->codecarbon) (2025.2)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.11/dist-packages (from pynvml->codecarbon) (12.570.86)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from questionary->codecarbon) (3.0.50)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->codecarbon) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->codecarbon) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->codecarbon) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->codecarbon) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->codecarbon) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->codecarbon) (2.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from typer->codecarbon) (4.13.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer->codecarbon) (1.5.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.0.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (0.14.0)
# Requirement already satisfied: cryptography>=3.4 in /usr/local/lib/python3.11/dist-packages (from jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (43.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->codecarbon) (0.1.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt_toolkit<4.0,>=2.0->questionary->codecarbon) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7.0->arrow->codecarbon) (1.17.0)
# Collecting termcolor<2.4.0,>=2.2.0 (from yaspin->fief-client[cli]->codecarbon)
#   Downloading termcolor-2.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (2.22)
# Downloading codecarbon-2.8.3-py3-none-any.whl (516 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.7/516.7 kB 18.0 MB/s eta 0:00:00
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 6.4 MB/s eta 0:00:00
# Downloading questionary-2.1.0-py3-none-any.whl (36 kB)
# Downloading rapidfuzz-3.12.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 75.8 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.9 MB/s eta 0:00:00
# Downloading jwcrypto-1.5.6-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 kB 10.2 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Downloading fief_client-0.20.0-py3-none-any.whl (20 kB)
# Downloading yaspin-3.1.0-py3-none-any.whl (18 kB)
# Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Installing collected packages: types-python-dateutil, termcolor, rapidfuzz, yaspin, questionary, httpx, arrow, jwcrypto, fief-client, codecarbon
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 3.0.0
#     Uninstalling termcolor-3.0.0:
#       Successfully uninstalled termcolor-3.0.0
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-genai 1.9.0 requires httpx<1.0.0,>=0.28.1, but you have httpx 0.27.2 which is incompatible.
# Successfully installed arrow-1.3.0 codecarbon-2.8.3 fief-client-0.20.0 httpx-0.27.2 jwcrypto-1.5.6 questionary-2.1.0 rapidfuzz-3.12.2 termcolor-2.3.0 types-python-dateutil-2.9.0.20241206 yaspin-3.1.0

# %%
import torch
import random
from PIL import Image
import numpy as np
import pandas as pd
import os
from decord import VideoReader, cpu

import kagglehub

import clip

from codecarbon import EmissionsTracker

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score
import seaborn as sns
import matplotlib.pyplot as plt

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
# print(f"GPU name: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.6.0+cu124
# CUDA available: True

# %%
# Download latest version
path = kagglehub.dataset_download("yash07yadav/project-data")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/project-data

# %%
# Load CLIP model
device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)

# Define multiple prompts for violence detection
violent_prompts = [
    "A brutal fight with multiple people engaged in violence.",
    "A person violently attacking another with punches and kicks.",
    "A chaotic fight scene with people punching and kicking each other."
]

non_violent_prompts = [
    "A peaceful gathering where people are standing and talking calmly.",
    "A person walking in a park with no conflict happening.",
    "An empty street with no visible fights or violence."
]

# Tokenize all prompts
text_inputs = clip.tokenize(violent_prompts + non_violent_prompts).to(device)

# Process frames
def classify_video(video_reader, frame_interval=10):
    violence_scores = []
    for i in range(0, len(video_reader), frame_interval):
        frame = video_reader[i].asnumpy()
        image = Image.fromarray(frame)
        image_input = preprocess(image).unsqueeze(0).to(device)
        with torch.no_grad():
            logits_per_image, _ = model(image_input, text_inputs)
            probs = logits_per_image.softmax(dim=-1).cpu().numpy()[0]
        violence_scores.append(probs[0])  # Probability of violence
    return np.mean(violence_scores)
# Out:
# 100%|████████████████████████████████████████| 338M/338M [00:03<00:00, 110MiB/s]

# %%
tracker = EmissionsTracker(project_name="LVLM Video Classification")

# Define paths
fight_dir = path + "/Complete Dataset/train/Fight/"
non_fight_dir = path + "/Complete Dataset/train/NonFight/"

# Function to get video files from a directory
def get_video_paths(directory, label):
    video_files = [f for f in os.listdir(directory) if f.endswith(('.mp4', '.avi', '.mov'))]
    return [{"video_path": os.path.join(directory, f), "label": label} for f in video_files]

# Load both Fight and NonFight videos
fight_videos = get_video_paths(fight_dir, 1)  # Label 1 for Fight
non_fight_videos = get_video_paths(non_fight_dir, 0)  # Label 0 for NonFight

# Combine and shuffle
all_videos = fight_videos + non_fight_videos
random.shuffle(all_videos)  # Shuffle to mix fight and non-fight videos

tracker.start()

# Process all videos
results = []
for video in all_videos:
    video_path = video["video_path"]
    label = video["label"]

    try:
        vr = VideoReader(video_path, ctx=cpu(0))
        score = classify_video(vr)  # Your classification function
        results.append({
            "video_path": video_path,
            "label": label,
            "violence_score": score,
            "prediction": "Violent" if score > 0.5 else "NonViolent"
        })
    except Exception as e:
        print(f"Error processing {video_path}: {str(e)}")

emissions = tracker.stop()

# Convert to DataFrame
results_df = pd.DataFrame(results)
print(results_df)
# Out:
# [codecarbon INFO @ 17:12:12] [setup] RAM Tracking...
# [codecarbon INFO @ 17:12:12] [setup] CPU Tracking...
# [codecarbon WARNING @ 17:12:12] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 17:12:14] We saw that you have a Intel(R) Xeon(R) CPU @ 2.00GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 17:12:14] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 17:12:14] [setup] GPU Tracking...
# [codecarbon INFO @ 17:12:14] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 17:12:14] >>> Tracker's metadata:
# [codecarbon INFO @ 17:12:14]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 17:12:14]   Python version: 3.11.11
# [codecarbon INFO @ 17:12:14]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 17:12:14]   Available RAM : 12.675 GB
# [codecarbon INFO @ 17:12:14]   CPU count: 2
# [codecarbon INFO @ 17:12:14]   CPU model: Intel(R) Xeon(R) CPU @ 2.00GHz
# [codecarbon INFO @ 17:12:14]   GPU count: 1
# [codecarbon INFO @ 17:12:14]   GPU model: 1 x Tesla T4
# [codecarbon INFO @ 17:12:14] Saving emissions data to file /content/emissions.csv
# [codecarbon INFO @ 17:12:30] Energy consumed for RAM : 0.000020 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:12:30] Energy consumed for all CPUs : 0.000177 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:12:30] Energy consumed for all GPUs : 0.000139 kWh. Total GPU Power : 33.27662558764892 W
# [codecarbon INFO @ 17:12:30] 0.000336 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:12:45] Energy consumed for RAM : 0.000040 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:12:45] Energy consumed for all CPUs : 0.000354 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:12:45] Energy consumed for all GPUs : 0.000280 kWh. Total GPU Power : 33.822726391857096 W
# [codecarbon INFO @ 17:12:45] 0.000673 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:13:00] Energy consumed for RAM : 0.000059 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:13:00] Energy consumed for all CPUs : 0.000531 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:13:00] Energy consumed for all GPUs : 0.000418 kWh. Total GPU Power : 33.25901753629599 W
# [codecarbon INFO @ 17:13:00] 0.001009 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:13:15] Energy consumed for RAM : 0.000079 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:13:15] Energy consumed for all CPUs : 0.000708 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:13:15] Energy consumed for all GPUs : 0.000564 kWh. Total GPU Power : 34.93720267117843 W
# [codecarbon INFO @ 17:13:15] 0.001351 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:13:30] Energy consumed for RAM : 0.000099 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:13:30] Energy consumed for all CPUs : 0.000885 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:13:30] Energy consumed for all GPUs : 0.000709 kWh. Total GPU Power : 34.82080626172912 W
# [codecarbon INFO @ 17:13:30] 0.001693 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:13:45] Energy consumed for RAM : 0.000119 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:13:45] Energy consumed for all CPUs : 0.001062 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:13:45] Energy consumed for all GPUs : 0.000854 kWh. Total GPU Power : 34.798905418153865 W
# [codecarbon INFO @ 17:13:45] 0.002035 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:14:00] Energy consumed for RAM : 0.000139 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:14:00] Energy consumed for all CPUs : 0.001239 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:14:00] Energy consumed for all GPUs : 0.001000 kWh. Total GPU Power : 35.14302111970364 W
# [codecarbon INFO @ 17:14:00] 0.002378 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:14:15] Energy consumed for RAM : 0.000158 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:14:15] Energy consumed for all CPUs : 0.001416 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:14:15] Energy consumed for all GPUs : 0.001146 kWh. Total GPU Power : 35.07724598046782 W
# [codecarbon INFO @ 17:14:15] 0.002721 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:14:15] 0.007916 g.CO2eq/s mean an estimation of 249.6453218165595 kg.CO2eq/year
# [codecarbon INFO @ 17:14:30] Energy consumed for RAM : 0.000178 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17
 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:17:30] Energy consumed for all GPUs : 0.003149 kWh. Total GPU Power : 38.798100523649 W
# [codecarbon INFO @ 17:17:30] 0.007283 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:17:45] Energy consumed for RAM : 0.000436 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:17:45] Energy consumed for all CPUs : 0.003895 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:17:45] Energy consumed for all GPUs : 0.003311 kWh. Total GPU Power : 38.75956726830724 W
# [codecarbon INFO @ 17:17:45] 0.007642 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:18:00] Energy consumed for RAM : 0.000455 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:18:00] Energy consumed for all CPUs : 0.004072 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:18:00] Energy consumed for all GPUs : 0.003472 kWh. Total GPU Power : 38.74725695201386 W
# [codecarbon INFO @ 17:18:00] 0.008000 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:18:15] Energy consumed for RAM : 0.000475 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:18:15] Energy consumed for all CPUs : 0.004249 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:18:15] Energy consumed for all GPUs : 0.003635 kWh. Total GPU Power : 38.9493978044601 W
# [codecarbon INFO @ 17:18:15] 0.008359 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:18:15] 0.008293 g.CO2eq/s mean an estimation of 261.5173867216191 kg.CO2eq/year
# [codecarbon INFO @ 17:18:30] Energy consumed for RAM : 0.000495 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:18:30] Energy consumed for all CPUs : 0.004426 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:18:30] Energy consumed for all GPUs : 0.003802 kWh. Total GPU Power : 40.139584592302064 W
# [codecarbon INFO @ 17:18:30] 0.008723 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:18:45] Energy consumed for RAM : 0.000515 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:18:45] Energy consumed for all CPUs : 0.004603 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:18:45] Energy consumed for all GPUs : 0.003966 kWh. Total GPU Power : 39.40370781265532 W
# [codecarbon INFO @ 17:18:45] 0.009084 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:19:00] Energy consumed for RAM : 0.000535 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:19:00] Energy consumed for all CPUs : 0.004781 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:19:00] Energy consumed for all GPUs : 0.004130 kWh. Total GPU Power : 39.351850327252215 W
# [codecarbon INFO @ 17:19:00] 0.009446 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:19:15] Energy consumed for RAM : 0.000554 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:19:15] Energy consumed for all CPUs : 0.004958 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:19:15] Energy consumed for all GPUs : 0.004292 kWh. Total GPU Power : 38.88044096920709 W
# [codecarbon INFO @ 17:19:15] 0.009805 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:19:30] Energy consumed for RAM : 0.000574 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:19:30] Energy consumed for all CPUs : 0.005135 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:19:30] Energy consumed for all GPUs : 0.004455 kWh. Total GPU Power : 39.162266924523614 W
# [codecarbon INFO @ 17:19:30] 0.010165 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:19:45] Energy consumed for RAM : 0.000594 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:19:45] Energy consumed for all CPUs : 0.005312 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:19:45] Energy consumed for all GPUs : 0.004619 kWh. Total GPU Power : 39.28068966801165 W
# [codecarbon INFO @ 17:19:45] 0.010525 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:20:00] Energy consumed for RAM : 0.000614 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:20:00] Energy consumed for all CPUs : 0.005489 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:20:00] Energy consumed for all GPUs : 0.004787 kWh. Total GPU Power : 40.21606750023819 W
# [codecarbon INFO @ 17:20:00] 0.010890 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:20:15] Energy consumed for RAM : 0.000634 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:20:15] Energy consumed for all CPUs : 0.005666 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:20:15] Energy consumed for all GPUs : 0.004951 kWh. Total GPU Power : 39.38526983745794 W
# [codecarbon INFO @ 17:20:15] 0.011250 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17
kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:23:15] Energy consumed for all GPUs : 0.006916 kWh. Total GPU Power : 39.308353014572525 W
# [codecarbon INFO @ 17:23:15] 0.015578 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:23:30] Energy consumed for RAM : 0.000891 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:23:30] Energy consumed for all CPUs : 0.007968 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:23:30] Energy consumed for all GPUs : 0.007082 kWh. Total GPU Power : 39.93487088577012 W
# [codecarbon INFO @ 17:23:30] 0.015941 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:23:45] Energy consumed for RAM : 0.000911 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:23:45] Energy consumed for all CPUs : 0.008145 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:23:45] Energy consumed for all GPUs : 0.007249 kWh. Total GPU Power : 40.03528159476453 W
# [codecarbon INFO @ 17:23:45] 0.016305 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:24:00] Energy consumed for RAM : 0.000931 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:24:00] Energy consumed for all CPUs : 0.008322 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:24:00] Energy consumed for all GPUs : 0.007411 kWh. Total GPU Power : 38.81233719466103 W
# [codecarbon INFO @ 17:24:00] 0.016663 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:24:15] Energy consumed for RAM : 0.000950 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:24:15] Energy consumed for all CPUs : 0.008499 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:24:15] Energy consumed for all GPUs : 0.007574 kWh. Total GPU Power : 39.17099610019501 W
# [codecarbon INFO @ 17:24:15] 0.017023 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:24:15] 0.008404 g.CO2eq/s mean an estimation of 265.0309470818059 kg.CO2eq/year
# [codecarbon INFO @ 17:24:30] Energy consumed for RAM : 0.000970 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:24:30] Energy consumed for all CPUs : 0.008676 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:24:30] Energy consumed for all GPUs : 0.007738 kWh. Total GPU Power : 39.43806748644972 W
# [codecarbon INFO @ 17:24:30] 0.017384 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:24:45] Energy consumed for RAM : 0.000990 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:24:45] Energy consumed for all CPUs : 0.008853 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:24:45] Energy consumed for all GPUs : 0.007904 kWh. Total GPU Power : 39.86988825248553 W
# [codecarbon INFO @ 17:24:45] 0.017747 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:25:00] Energy consumed for RAM : 0.001010 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:25:00] Energy consumed for all CPUs : 0.009030 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:25:00] Energy consumed for all GPUs : 0.008064 kWh. Total GPU Power : 38.42508405454323 W
# [codecarbon INFO @ 17:25:00] 0.018104 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:25:15] Energy consumed for RAM : 0.001030 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:25:15] Energy consumed for all CPUs : 0.009207 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:25:15] Energy consumed for all GPUs : 0.008226 kWh. Total GPU Power : 38.77373234148163 W
# [codecarbon INFO @ 17:25:15] 0.018463 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:25:30] Energy consumed for RAM : 0.001049 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:25:30] Energy consumed for all CPUs : 0.009384 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:25:30] Energy consumed for all GPUs : 0.008391 kWh. Total GPU Power : 39.49437578052349 W
# [codecarbon INFO @ 17:25:30] 0.018824 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:25:45] Energy consumed for RAM : 0.001069 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:25:45] Energy consumed for all CPUs : 0.009561 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:25:45] Energy consumed for all GPUs : 0.008554 kWh. Total GPU Power : 39.261509042178176 W
# [codecarbon INFO @ 17:25:45] 0.019184 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:26:00] Energy consumed for RAM : 0.001089 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:26:00] Energy consumed for all CPUs : 0.009738 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:26:00] Energy consumed for all GPUs : 0.008721 kWh. Total GPU Power : 40.137514211570924 W
# [codecarbon INFO @ 17:26:00] 0.019548 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17
kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:29:00] Energy consumed for all CPUs : 0.011862 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:29:00] Energy consumed for all GPUs : 0.010695 kWh. Total GPU Power : 39.71755717321314 W
# [codecarbon INFO @ 17:29:00] 0.023884 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:29:15] Energy consumed for RAM : 0.001346 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:29:15] Energy consumed for all CPUs : 0.012040 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:29:15] Energy consumed for all GPUs : 0.010859 kWh. Total GPU Power : 39.395889399063414 W
# [codecarbon INFO @ 17:29:15] 0.024245 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:29:30] Energy consumed for RAM : 0.001366 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:29:30] Energy consumed for all CPUs : 0.012217 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:29:30] Energy consumed for all GPUs : 0.011022 kWh. Total GPU Power : 38.96788902070439 W
# [codecarbon INFO @ 17:29:30] 0.024604 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:29:45] Energy consumed for RAM : 0.001386 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:29:45] Energy consumed for all CPUs : 0.012394 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:29:45] Energy consumed for all GPUs : 0.011185 kWh. Total GPU Power : 39.38330148810541 W
# [codecarbon INFO @ 17:29:45] 0.024965 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:30:00] Energy consumed for RAM : 0.001406 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:30:00] Energy consumed for all CPUs : 0.012571 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:30:00] Energy consumed for all GPUs : 0.011352 kWh. Total GPU Power : 40.06536233512538 W
# [codecarbon INFO @ 17:30:00] 0.025329 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:30:15] Energy consumed for RAM : 0.001425 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:30:15] Energy consumed for all CPUs : 0.012748 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:30:15] Energy consumed for all GPUs : 0.011514 kWh. Total GPU Power : 38.727307175142364 W
# [codecarbon INFO @ 17:30:15] 0.025687 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:30:15] 0.008401 g.CO2eq/s mean an estimation of 264.9391096359737 kg.CO2eq/year
# [codecarbon INFO @ 17:30:30] Energy consumed for RAM : 0.001445 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:30:30] Energy consumed for all CPUs : 0.012925 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:30:30] Energy consumed for all GPUs : 0.011679 kWh. Total GPU Power : 39.68213524940175 W
# [codecarbon INFO @ 17:30:30] 0.026049 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:30:45] Energy consumed for RAM : 0.001465 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:30:45] Energy consumed for all CPUs : 0.013102 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:30:45] Energy consumed for all GPUs : 0.011843 kWh. Total GPU Power : 39.44484301899203 W
# [codecarbon INFO @ 17:30:45] 0.026410 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:31:00] Energy consumed for RAM : 0.001485 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:31:00] Energy consumed for all CPUs : 0.013279 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:31:00] Energy consumed for all GPUs : 0.012010 kWh. Total GPU Power : 39.967498420161384 W
# [codecarbon INFO @ 17:31:00] 0.026774 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:31:15] Energy consumed for RAM : 0.001505 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:31:15] Energy consumed for all CPUs : 0.013456 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:31:15] Energy consumed for all GPUs : 0.012176 kWh. Total GPU Power : 39.84258580691183 W
# [codecarbon INFO @ 17:31:15] 0.027137 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:31:30] Energy consumed for RAM : 0.001524 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:31:30] Energy consumed for all CPUs : 0.013633 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:31:30] Energy consumed for all GPUs : 0.012341 kWh. Total GPU Power : 39.512305712280714 W
# [codecarbon INFO @ 17:31:30] 0.027498 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:31:45] Energy consumed for RAM : 0.001544 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:31:45] Energy consumed for all CPUs : 0.013810 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:31:45] Energy consumed for all GPUs : 0.012505 kWh. Total GPU Power : 39.495952596489396 W
# [codecarbon INFO @ 17:31:45] 0.027859 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:32:00] Energy consumed for RAM : 0.001564 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:32:00] Energy consumed for all CPUs : 0.013987 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:32:00] Energy consumed for all GPUs : 0.012665 kWh. Total GPU Power : 38.46936001855108 W
# [codecarbon INFO @ 17:32:00] 0.028216 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:32:15] Energy consumed for RAM : 0.001584 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:32:15] Energy consumed for all CPUs : 0.014164 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:32:15] Energy consumed for all GPUs : 0.012827 kWh. Total GPU Power : 38.79116641735788 W
# [codecarbon INFO @ 17:32:15] 0.028575 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:32:15] 0.008402 g.CO2eq/s mean an estimation of 264.96023366050446 kg.CO2eq/year
# [codecarbon INFO @ 17:32:30] Energy consumed for RAM : 0.001604 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:32:30] Energy consumed for all CPUs : 0.014341 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:32:30] Energy consumed for all GPUs : 0.012993 kWh. Total GPU Power : 39.775927363258525 W
# [codecarbon INFO @ 17:32:30] 0.028938 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:32:45] Energy consumed for RAM : 0.001623 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:32:45] Energy consumed for all CPUs : 0.014518 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:32:45] Energy consumed for all GPUs : 0.013156 kWh. Total GPU Power : 39.23809299534255 W
# [codecarbon INFO @ 17:32:45] 0.029298 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:33:00] Energy consumed for RAM : 0.001643 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:33:00] Energy consumed for all CPUs : 0.014695 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:33:00] Energy consumed for all GPUs : 0.013321 kWh. Total GPU Power : 39.439835809828075 W
# [codecarbon INFO @ 17:33:00] 0.029659 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:33:15] Energy consumed for RAM : 0.001663 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:33:15] Energy consumed for all CPUs : 0.014872 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:33:15] Energy consumed for all GPUs : 0.013486 kWh. Total GPU Power : 39.62184871586727 W
# [codecarbon INFO @ 17:33:15] 0.030021 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:33:30] Energy consumed for RAM : 0.001683 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:33:30] Energy consumed for all CPUs : 0.015049 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:33:30] Energy consumed for all GPUs : 0.013652 kWh. Total GPU Power : 40.00960443240622 W
# [codecarbon INFO @ 17:33:30] 0.030384 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:33:45] Energy consumed for RAM : 0.001703 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:33:45] Energy consumed for all CPUs : 0.015227 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:33:45] Energy consumed for all GPUs : 0.013817 kWh. Total GPU Power : 39.475751733715754 W
# [codecarbon INFO @ 17:33:45] 0.030747 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:34:00] Energy consumed for RAM : 0.001722 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:34:00] Energy consumed for all CPUs : 0.015404 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:34:00] Energy consumed for all GPUs : 0.013977 kWh. Total GPU Power : 38.457387948214574 W
# [codecarbon INFO @ 17:34:00] 0.031104 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:34:15] Energy consumed for RAM : 0.001742 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:34:15] Energy consumed for all CPUs : 0.015581 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:34:15] Energy consumed for all GPUs : 0.014141 kWh. Total GPU Power : 39.34562245682381 W
# [codecarbon INFO @ 17:34:15] 0.031464 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:34:15] 0.008404 g.CO2eq/s mean an estimation of 265.0393501087899 kg.CO2eq/year
# [codecarbon INFO @ 17:34:28] Energy consumed for RAM : 0.001759 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 17:34:28] Energy consumed for all CPUs : 0.015734 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:34:28] Energy consumed for all GPUs : 0.014282 kWh. Total GPU Power : 39.049942100123076 W
# [codecarbon INFO @ 17:34:28] 0.031776 kWh of electricity used since the beginning.
#                                              video_path  label  \
# 0     /kaggle/input/project-data/Complete Dataset/tr...      1
# 1     /kaggle/input/project-data/Complete Dataset/tr...      0
# 2     /kaggle/input/project-data/Complete Dataset/tr...      0
# 3     /kaggle/input/project-data/Complete Dataset/tr...      1
# 4     /kaggle/input/project-data/Complete Dataset/tr...      0
# ...                                                 ...    ...
# 1995  /kaggle/input/project-data/Complete Dataset/tr...      1
# 1996  /kaggle/input/project-data/Complete Dataset/tr...      1
# 1997  /kaggle/input/project-data/Complete Dataset/tr...      0
# 1998  /kaggle/input/project-data/Complete Dataset/tr...      0
# 1999  /kaggle/input/project-data/Complete Dataset/tr...      0
#
#       violence_score  prediction
# 0           0.437256  NonViolent
# 1           0.289551  NonViolent
# 2           0.145996  NonViolent
# 3           0.629883     Violent
# 4           0.126343  NonViolent
# ...              ...         ...
# 1995        0.262695  NonViolent
# 1996        0.054352  NonViolent
# 1997        0.390869  NonViolent
# 1998        0.031494  NonViolent
# 1999        0.082764  NonViolent
#
# [2000 rows x 4 columns]
# /usr/local/lib/python3.11/dist-packages/codecarbon/output_methods/file.py:52: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame.from_records([dict(total.values)])])
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()

# %%
# Get true labels from the DataFrame
true_labels = results_df["label"].tolist()

# Predicted labels based on the violence score threshold (0.5)
pred_labels = [1 if row["prediction"] == "Violent" else 0 for _, row in results_df.iterrows()]

# Accuracy & Classification Report
accuracy = accuracy_score(true_labels, pred_labels)
print(f"Accuracy: {accuracy:.4f}")
print("\nClassification Report:\n", classification_report(true_labels, pred_labels))

# Confusion Matrix
cm = confusion_matrix(true_labels, pred_labels)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["NonFight", "Fight"], yticklabels=["NonFight", "Fight"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# ROC-AUC Score
roc_auc = roc_auc_score(true_labels, pred_labels)
print(f"ROC-AUC Score: {roc_auc:.4f}")
# Out:
# Accuracy: 0.4840
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.49      0.95      0.65      1000
#            1       0.29      0.02      0.04      1000
#
#     accuracy                           0.48      2000
#    macro avg       0.39      0.48      0.34      2000
# weighted avg       0.39      0.48      0.34      2000
# ROC-AUC Score: 0.4840

# %%
# Get energy usage details
emissions = tracker.final_emissions_data.emissions
energy_consumed = tracker.final_emissions_data.energy_consumed
duration = tracker.final_emissions_data.duration
cpu_energy = tracker.final_emissions_data.cpu_energy
gpu_energy = tracker.final_emissions_data.gpu_energy
ram_energy = tracker.final_emissions_data.ram_energy

print(f"Emissions: {emissions:.4f} kWh")
print(f"Total Energy: {energy_consumed:.4f} kWh")
print(f"Duration: {duration:.2f} seconds")
print(f"CPU Energy: {cpu_energy:.4f} kWh")
print(f"GPU Energy: {gpu_energy:.4f} kWh")
print(f"RAM Energy: {ram_energy:.4f} kWh")
# Out:
# Emissions: 0.0111 kWh
# Total Energy: 0.0318 kWh
# Duration: 1333.59 seconds
# CPU Energy: 0.0157 kWh
# GPU Energy: 0.0143 kWh
# RAM Energy: 0.0018 kWh
